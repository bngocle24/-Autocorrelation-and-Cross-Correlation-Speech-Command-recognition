# %%
pip install librosa sounddevice wavio matplotlib numpy
# Out:
# Requirement already satisfied: librosa in c:\users\ngoc\anaconda3\lib\site-packages (0.10.2.post1)
# Requirement already satisfied: sounddevice in c:\users\ngoc\anaconda3\lib\site-packages (0.4.7)
# Requirement already satisfied: wavio in c:\users\ngoc\anaconda3\lib\site-packages (0.0.9)
# Requirement already satisfied: matplotlib in c:\users\ngoc\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: numpy in c:\users\ngoc\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\ngoc\anaconda3\lib\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\ngoc\anaconda3\lib\site-packages (from librosa) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\ngoc\anaconda3\lib\site-packages (from librosa) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in c:\users\ngoc\anaconda3\lib\site-packages (from librosa) (1.2.0)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\ngoc\anaconda3\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\ngoc\anaconda3\lib\site-packages (from librosa) (0.59.0)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\ngoc\anaconda3\lib\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.1 in c:\users\ngoc\anaconda3\lib\site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\ngoc\anaconda3\lib\site-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\ngoc\anaconda3\lib\site-packages (from librosa) (4.9.0)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\ngoc\anaconda3\lib\site-packages (from librosa) (0.3)
# Requirement already satisfied: msgpack>=1.0 in c:\users\ngoc\anaconda3\lib\site-packages (from librosa) (1.0.3)
# Requirement already satisfied: CFFI>=1.0 in c:\users\ngoc\anaconda3\lib\site-packages (from sounddevice) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ngoc\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ngoc\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ngoc\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ngoc\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ngoc\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ngoc\anaconda3\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ngoc\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ngoc\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pycparser in c:\users\ngoc\anaconda3\lib\site-packages (from CFFI>=1.0->sounddevice) (2.21)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\ngoc\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (0.42.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\ngoc\anaconda3\lib\site-packages (from pooch>=1.1->librosa) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\ngoc\anaconda3\lib\site-packages (from pooch>=1.1->librosa) (2.31.0)
# Requirement already satisfied: six>=1.5 in c:\users\ngoc\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ngoc\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ngoc\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ngoc\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ngoc\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ngoc\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa
import sounddevice as sd
import wavio

# Function to record audio samples
def record_sample(duration=2, fs=44100):
    print("Recording...")
    sample = sd.rec(int(duration * fs), samplerate=fs, channels=1, dtype='float64')
    sd.wait()  # Wait until recording is finished
    sample = sample.flatten()
    print("Recording finished.")
    return sample, fs

# Load the reference audio files
tatt_signal, tatt_sr = librosa.load('1.wav', sr=None)
mo_signal, mo_sr = librosa.load('2.wav', sr=None)

# Normalize the signals
tatt_signal = tatt_signal / np.max(np.abs(tatt_signal))
mo_signal = mo_signal / np.max(np.abs(mo_signal))

# Record a test command with a duration of 5 seconds
print('Recording test command (5 seconds):')
test_signal, test_sr = record_sample(duration=5)

# Normalize the test signal
test_signal = test_signal / np.max(np.abs(test_signal))

# Calculate cross-correlation
cross_corr_tatt = np.correlate(test_signal, tatt_signal, mode='full')
cross_corr_mo = np.correlate(test_signal, mo_signal, mode='full')

# Find the highest peak in the cross-correlation
max_corr_tatt = np.max(np.abs(cross_corr_tatt))
max_corr_mo = np.max(np.abs(cross_corr_mo))

# Determine which command the test sample matches
if max_corr_tatt > max_corr_mo:
    recognized_command = 'tắt'
else:
    recognized_command = 'mở'

# Display results
print(f'Recognized command: {recognized_command}')

# Plot waveforms
plt.figure(figsize=(15, 10))

# Plot 1.wav waveform
plt.subplot(3, 1, 1)
plt.plot(tatt_signal, label='1.wav (tắt)')
plt.title('1.wav (tắt)')
plt.xlabel('Sample')
plt.ylabel('Amplitude')
plt.legend()

# Plot 2.wav waveform
plt.subplot(3, 1, 2)
plt.plot(mo_signal, label='2.wav (mở)')
plt.title('2.wav (mở)')
plt.xlabel('Sample')
plt.ylabel('Amplitude')
plt.legend()

# Plot test waveform
plt.subplot(3, 1, 3)
plt.plot(test_signal, label='Test')
plt.title('Test Command')
plt.xlabel('Sample')
plt.ylabel('Amplitude')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Recording test command (5 seconds):
# Recording...
# Recording finished.
